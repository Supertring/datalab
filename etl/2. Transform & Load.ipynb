# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3

# %% [markdown]
# __Task : Handling Irregular and Unsuable Data__
#
# * Data have thousands of records and there can be irregularities in datasets
# * Chance of some corrupt or faulty data
# * Because of data entry error or something else
# * Find any unusable data and deal with it, to avoid issues
# * Eg: user ages may have been recorded incorrectly
# * Check for evidence and take appropriate actions

# %%
users_w_devices_and_transactions = pd.read_csv('datasets/users_w_devices_and_transactions.csv')

# %%
users_w_devices_and_transactions.head(n=6)
# Out:
#                                 user_id  number_transactions  \
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
# 2  573de577-49ef-42b9-83da-d3cfb817b5c1                  2.0
# 3  d6b66b9d-7c8f-4257-a682-e136f640b7e3                  NaN
# 4  fade0b20-7594-4d9a-84cd-c02f79b1b526                  1.0
# 5  c6aee0d4-2a86-4bac-827b-c6d33b5933e6                  2.0
#
#    total_amount_usd  age           job  marital  education default housing  \
# 0            2143.0   58    management  married   tertiary      no     yes
# 1               NaN   44    technician   single  secondary      no     yes
# 2               2.0   33  entrepreneur  married  secondary      no     yes
# 3               NaN   47   blue-collar  married        NaN      no     yes
# 4               1.0   33           NaN   single        NaN      no      no
# 5             231.0   35    management  married   tertiary      no     yes
#
#   loan contact  duration  campaign  pdays  previous poutcome term_deposit  \
# 0   no     NaN       261         1     -1         0      NaN           no
# 1   no     NaN       151         1     -1         0      NaN           no
# 2  yes     NaN        76         1     -1         0      NaN           no
# 3   no     NaN        92         1     -1         0      NaN           no
# 4   no     NaN       198         1     -1         0      NaN           no
# 5   no     NaN       139         1     -1         0      NaN           no
#
#   date_joined   device
# 0  1998-08-23   mobile
# 1  2008-07-15  desktop
# 2  2002-06-04   mobile
# 3  1995-06-29   tablet
# 4  1995-08-01   mobile
# 5  2000-06-21  desktop

# %% [markdown]
# > Identify users with age greater than 150, as age higher than 150 can be an faulty data
#
# * Below shows two data points have age above 150, which is fault data

# %%
users_w_devices_and_transactions[users_w_devices_and_transactions['age']>150]
# Out:
#                                     user_id  number_transactions  \
# 7228   44fefdad-7045-4be5-890e-12e84ae6fdc9                  NaN
# 10318  9b2cd5d2-900e-4052-831f-6489f6d568af                  2.0
#
#        total_amount_usd  age          job  marital education default housing  \
# 7228                NaN  178  blue-collar  married   primary      no     yes
# 10318            3165.0  891   management  married  tertiary      no     yes
#
#       loan contact  duration  campaign  pdays  previous poutcome term_deposit  \
# 7228    no     NaN       691         1     -1         0      NaN           no
# 10318   no     NaN       278         2     -1         0      NaN           no
#
#       date_joined   device
# 7228   1997-04-28  desktop
# 10318  2003-10-03   mobile

# %% [markdown]
# __Task__:
# * Drop incorrect data
# * Age above 150 is not logical and corrupted

# %%
users_cleaned = users_w_devices_and_transactions[users_w_devices_and_transactions.age < 150]

# %%
users_cleaned.shape
# Out:
# (45214, 19)

# %% [markdown]
# __Task__
# * Identify more potentially erroneous data
# * Compare age to device.

# %%
electronic_user_freq = pd.crosstab(users_cleaned['age'], users_cleaned['device']).reset_index()

# %%
fig, axes = plt.subplots(3,1, figsize=(18,10))
sns.barplot(ax=axes[0], x='age', y='desktop', data=electronic_user_freq)
sns.barplot(ax=axes[1], x='age', y='mobile', data=electronic_user_freq)
sns.barplot(ax=axes[2], x='age', y='tablet', data=electronic_user_freq)
# Out:
# <AxesSubplot:xlabel='age', ylabel='tablet'>

# %% [markdown]
# __Analysis__
# * The above frequencey plot shows, younger users are more likely to use electronic devices to do their banking than old people
# * As the age increase the use of desktop, mobile and tablet increases and as the age grows towards old age the use decreases

# %% [markdown]
# # Correcting Data Formats
#
# * All data types in the datasets are cast correctly
# * But need to convert string objects to boolean values, since some columns should be `true` or `false`
# * Also date and time for cast as string, and need to convert it into date time format for easy processing

# %%
users_cleaned.head()
# Out:
#                                 user_id  number_transactions  \
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
# 2  573de577-49ef-42b9-83da-d3cfb817b5c1                  2.0
# 3  d6b66b9d-7c8f-4257-a682-e136f640b7e3                  NaN
# 4  fade0b20-7594-4d9a-84cd-c02f79b1b526                  1.0
#
#    total_amount_usd  age           job  marital  education default housing  \
# 0            2143.0   58    management  married   tertiary      no     yes
# 1               NaN   44    technician   single  secondary      no     yes
# 2               2.0   33  entrepreneur  married  secondary      no     yes
# 3               NaN   47   blue-collar  married        NaN      no     yes
# 4               1.0   33           NaN   single        NaN      no      no
#
#   loan contact  duration  campaign  pdays  previous poutcome term_deposit  \
# 0   no     NaN       261         1     -1         0      NaN           no
# 1   no     NaN       151         1     -1         0      NaN           no
# 2  yes     NaN        76         1     -1         0      NaN           no
# 3   no     NaN        92         1     -1         0      NaN           no
# 4   no     NaN       198         1     -1         0      NaN           no
#
#   date_joined   device
# 0  1998-08-23   mobile
# 1  2008-07-15  desktop
# 2  2002-06-04   mobile
# 3  1995-06-29   tablet
# 4  1995-08-01   mobile

# %%
users_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45214 entries, 0 to 45215
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45214 non-null  object
#  1   number_transactions  35215 non-null  float64
#  2   total_amount_usd     35215 non-null  float64
#  3   age                  45214 non-null  int64
#  4   job                  44926 non-null  object
#  5   marital              45214 non-null  object
#  6   education            43357 non-null  object
#  7   default              45214 non-null  object
#  8   housing              45214 non-null  object
#  9   loan                 45214 non-null  object
#  10  contact              32196 non-null  object
#  11  duration             45214 non-null  int64
#  12  campaign             45214 non-null  int64
#  13  pdays                45214 non-null  int64
#  14  previous             45214 non-null  int64
#  15  poutcome             8255 non-null   object
#  16  term_deposit         45214 non-null  object
#  17  date_joined          45184 non-null  object
#  18  device               45120 non-null  object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 6.9+ MB

# %%
users_cleaned.default.value_counts()
# Out:
# no     44398
# yes      816
# Name: default, dtype: int64

# %% [markdown]
# > `default` variable only have yes/no values in string object, it would be better if there are cast as booleans

# %% [markdown]
# __Task__
# * Convert the relevant variables to a Boolean type.

# %%
users_cleaned_1 = users_cleaned.copy() # work with a new object
users_cleaned_1.default = users_cleaned_1.default.map(dict(yes=1, no=0)).astype(bool)

# %%
users_cleaned_1.default.value_counts()
# Out:
# False    44398
# True       816
# Name: default, dtype: int64

# %%
# do the same for other variables as well

bool_vars = ['housing', 'loan', 'term_deposit']

for var in bool_vars:
    users_cleaned_1[var] = users_cleaned_1[var].map(dict(yes=1, no=0)).astype(bool)
    print(f'Converted {var} to Boolean.')
# Out:
# Converted housing to Boolean.
# Converted loan to Boolean.
# Converted term_deposit to Boolean.

# %%
users_cleaned_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45214 entries, 0 to 45215
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45214 non-null  object
#  1   number_transactions  35215 non-null  float64
#  2   total_amount_usd     35215 non-null  float64
#  3   age                  45214 non-null  int64
#  4   job                  44926 non-null  object
#  5   marital              45214 non-null  object
#  6   education            43357 non-null  object
#  7   default              45214 non-null  bool
#  8   housing              45214 non-null  bool
#  9   loan                 45214 non-null  bool
#  10  contact              32196 non-null  object
#  11  duration             45214 non-null  int64
#  12  campaign             45214 non-null  int64
#  13  pdays                45214 non-null  int64
#  14  previous             45214 non-null  int64
#  15  poutcome             8255 non-null   object
#  16  term_deposit         45214 non-null  bool
#  17  date_joined          45184 non-null  object
#  18  device               45120 non-null  object
# dtypes: bool(4), float64(2), int64(5), object(8)
# memory usage: 5.7+ MB

# %% [markdown]
# __Task__
# * Convert date to date time format

# %%
users_cleaned_2 = users_cleaned_1.copy() # work with a new object

# %%
users_cleaned_2['date_joined'] = pd.to_datetime(users_cleaned_2['date_joined'], format='%Y-%m-%d')

# %%
users_cleaned_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45214 entries, 0 to 45215
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45214 non-null  object
#  1   number_transactions  35215 non-null  float64
#  2   total_amount_usd     35215 non-null  float64
#  3   age                  45214 non-null  int64
#  4   job                  44926 non-null  object
#  5   marital              45214 non-null  object
#  6   education            43357 non-null  object
#  7   default              45214 non-null  bool
#  8   housing              45214 non-null  bool
#  9   loan                 45214 non-null  bool
#  10  contact              32196 non-null  object
#  11  duration             45214 non-null  int64
#  12  campaign             45214 non-null  int64
#  13  pdays                45214 non-null  int64
#  14  previous             45214 non-null  int64
#  15  poutcome             8255 non-null   object
#  16  term_deposit         45214 non-null  bool
#  17  date_joined          45184 non-null  datetime64[ns]
#  18  device               45120 non-null  object
# dtypes: bool(4), datetime64[ns](1), float64(2), int64(5), object(7)
# memory usage: 5.7+ MB

# %% [markdown]
# #

# %% [markdown]
# # Deduplicating Data
#
# * Large datasets is the presence of duplicates
# * identify duplicate rows and then remove them from the dataset

# %%
# identify the duplicate data

duplicate_data = users_cleaned_2[users_cleaned_2.duplicated(keep=False)]

# %%
duplicate_data.shape
# Out:
# (10, 19)

# %%
duplicate_data
# Out:
#                                     user_id  number_transactions  \
# 15456  cba59442-af3c-41d7-a39c-0f9bffba0660                  2.0
# 22005  1e826721-b38c-41c2-88f4-4c28b335b1e6                  4.0
# 35413  a2fb8264-d55a-437b-a8e7-9ec4116b76f4                  2.0
# 35620  f49ac08f-b872-4d57-ac82-9b8a9144020d                  4.0
# 36292  ae3b92a2-cad8-434f-8037-9815e2228839                  2.0
# 45211  cba59442-af3c-41d7-a39c-0f9bffba0660                  2.0
# 45212  1e826721-b38c-41c2-88f4-4c28b335b1e6                  4.0
# 45213  a2fb8264-d55a-437b-a8e7-9ec4116b76f4                  2.0
# 45214  ae3b92a2-cad8-434f-8037-9815e2228839                  2.0
# 45215  f49ac08f-b872-4d57-ac82-9b8a9144020d                  4.0
#
#        total_amount_usd  age          job  marital  education  default  \
# 15456            1218.0   57   management  married   tertiary     True
# 22005             159.0   31   technician   single  secondary    False
# 35413             676.0   34   management  married   tertiary    False
# 35620             117.0   38  blue-collar  married  secondary    False
# 36292             426.0   43       admin.   single  secondary    False
# 45211            1218.0   57   management  married   tertiary     True
# 45212             159.0   31   technician   single  secondary    False
# 45213             676.0   34   management  married   tertiary    False
# 45214             426.0   43       admin.   single  secondary    False
# 45215             117.0   38  blue-collar  married  secondary    False
#
#        housing   loan   contact  duration  campaign  pdays  previous poutcome  \
# 15456     True  False  cellular       317         6     -1         0      NaN
# 22005    False  False  cellular       129         1     -1         0      NaN
# 35413    False  False  cellular       156         1    177         1  success
# 35620     True  False  cellular        54         1    337         1  failure
# 36292     True  False  cellular        76         2    304         2  failure
# 45211     True  False  cellular       317         6     -1         0      NaN
# 45212    False  False  cellular       129         1     -1         0      NaN
# 45213    False  False  cellular       156         1    177         1  success
# 45214     True  False  cellular        76         2    304         2  failure
# 45215     True  False  cellular        54         1    337         1  failure
#
#        term_deposit date_joined   device
# 15456         False  1993-02-27  desktop
# 22005         False  1990-05-10   mobile
# 35413         False  1989-09-02   mobile
# 35620         False  2010-06-11   mobile
# 36292         False  1992-10-29  desktop
# 45211         False  1993-02-27  desktop
# 45212         False  1990-05-10   mobile
# 45213         False  1989-09-02   mobile
# 45214         False  1992-10-29  desktop
# 45215         False  2010-06-11   mobile

# %%
users_cleaned_final = users_cleaned_2[~users_cleaned_2.duplicated()]

# %%
# verify if the duplicate data now exists only once
users_cleaned_final[users_cleaned_final['user_id'] == 'cba59442-af3c-41d7-a39c-0f9bffba0660']
# Out:
#                                     user_id  number_transactions  \
# 15456  cba59442-af3c-41d7-a39c-0f9bffba0660                  2.0
#
#        total_amount_usd  age         job  marital education  default  housing  \
# 15456            1218.0   57  management  married  tertiary     True     True
#
#         loan   contact  duration  campaign  pdays  previous poutcome  \
# 15456  False  cellular       317         6     -1         0      NaN
#
#        term_deposit date_joined   device
# 15456         False  1993-02-27  desktop

# %%
users_cleaned_final.shape
# Out:
# (45209, 19)

# %% [markdown]
# # Load Data

# %% [markdown]
# # Load data into an SQL database

# %%
conn = sqlite3.connect('datasets/users_data_cleaned.db')
users_cleaned_final.to_sql('users_cleaned_final', conn, if_exists='replace', index=False)
# Out:
# 45209

# %%
query = "SELECT * FROM users_cleaned_final"
pd.read_sql(query, conn).head()
# Out:
#                                 user_id  number_transactions  \
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
# 2  573de577-49ef-42b9-83da-d3cfb817b5c1                  2.0
# 3  d6b66b9d-7c8f-4257-a682-e136f640b7e3                  NaN
# 4  fade0b20-7594-4d9a-84cd-c02f79b1b526                  1.0
#
#    total_amount_usd  age           job  marital  education  default  housing  \
# 0            2143.0   58    management  married   tertiary        0        1
# 1               NaN   44    technician   single  secondary        0        1
# 2               2.0   33  entrepreneur  married  secondary        0        1
# 3               NaN   47   blue-collar  married       None        0        1
# 4               1.0   33          None   single       None        0        0
#
#    loan contact  duration  campaign  pdays  previous poutcome  term_deposit  \
# 0     0    None       261         1     -1         0     None             0
# 1     0    None       151         1     -1         0     None             0
# 2     1    None        76         1     -1         0     None             0
# 3     0    None        92         1     -1         0     None             0
# 4     0    None       198         1     -1         0     None             0
#
#            date_joined   device
# 0  1998-08-23 00:00:00   mobile
# 1  2008-07-15 00:00:00  desktop
# 2  2002-06-04 00:00:00   mobile
# 3  1995-06-29 00:00:00   tablet
# 4  1995-08-01 00:00:00   mobile

# %%
# close the database connection
conn.close()

# %% [markdown]
# __Confirm the database file was saved to the local drive__

# %% [markdown]
# # Load: Write data as Pickle File Format

# %%
# write data to pickle file
users_cleaned_final.to_pickle('datasets/users_cleaned_final.pickle')

# %%
# confirm that the data was written to the pickle file
pd.read_pickle('datasets/users_cleaned_final.pickle').head(n=2)
# Out:
#                                 user_id  number_transactions  \
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
#
#    total_amount_usd  age         job  marital  education  default  housing  \
# 0            2143.0   58  management  married   tertiary    False     True
# 1               NaN   44  technician   single  secondary    False     True
#
#     loan contact  duration  campaign  pdays  previous poutcome  term_deposit  \
# 0  False     NaN       261         1     -1         0      NaN         False
# 1  False     NaN       151         1     -1         0      NaN         False
#
#   date_joined   device
# 0  1998-08-23   mobile
# 1  2008-07-15  desktop

# %%
pd.read_pickle('datasets/users_cleaned_final.pickle').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45209 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45209 non-null  object
#  1   number_transactions  35210 non-null  float64
#  2   total_amount_usd     35210 non-null  float64
#  3   age                  45209 non-null  int64
#  4   job                  44921 non-null  object
#  5   marital              45209 non-null  object
#  6   education            43352 non-null  object
#  7   default              45209 non-null  bool
#  8   housing              45209 non-null  bool
#  9   loan                 45209 non-null  bool
#  10  contact              32191 non-null  object
#  11  duration             45209 non-null  int64
#  12  campaign             45209 non-null  int64
#  13  pdays                45209 non-null  int64
#  14  previous             45209 non-null  int64
#  15  poutcome             8252 non-null   object
#  16  term_deposit         45209 non-null  bool
#  17  date_joined          45179 non-null  datetime64[ns]
#  18  device               45115 non-null  object
# dtypes: bool(4), datetime64[ns](1), float64(2), int64(5), object(7)
# memory usage: 5.7+ MB

# %% [markdown]
# # Load: Exporting Data to a CSV File Format

# %%
# Write data to csv
users_cleaned_final.to_csv('datasets/users_data_cleaned.csv', index=False)

# %%
pd.read_csv('datasets/users_data_cleaned.csv').head(n=2)
# Out:
#                                 user_id  number_transactions  \
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
#
#    total_amount_usd  age         job  marital  education  default  housing  \
# 0            2143.0   58  management  married   tertiary    False     True
# 1               NaN   44  technician   single  secondary    False     True
#
#     loan contact  duration  campaign  pdays  previous poutcome  term_deposit  \
# 0  False     NaN       261         1     -1         0      NaN         False
# 1  False     NaN       151         1     -1         0      NaN         False
#
#   date_joined   device
# 0  1998-08-23   mobile
# 1  2008-07-15  desktop

# %% [markdown]
# # Handling Textual Data
#
# * Consumer complaints data  can be of value for nlp exploration
# * handling textual data is different than numeric and categorical data
# * need a way to process the text, so its more conducive to analysis and machine learning

# %%
complaints_data = pd.read_csv('datasets/consumer_loan_complaints.csv')
complaints_data.head()
# Out:
#                                 user_id Date received        Product  \
# 0  44fefdad-7045-4be5-890e-12e84ae6fdc9    01/27/2016  Consumer Loan
# 1  c49d5d60-909f-406b-b7ff-51143fcb650b    08/26/2014  Consumer Loan
# 2  9b2cd5d2-900e-4052-831f-6489f6d568af    08/22/2012  Consumer Loan
# 3  b7e5b324-268e-4502-81a1-1a025673c2a0    05/07/2013  Consumer Loan
# 4  684eeb4c-c9c3-4a97-8213-f3962a6c0aba    06/15/2016  Consumer Loan
#
#                                  Issue Consumer complaint narrative State  \
# 0            Account terms and changes                          NaN    AL
# 1            Account terms and changes                          NaN    NC
# 2            Account terms and changes                          NaN    TN
# 3  Problems when you are unable to pay                          NaN    OH
# 4          Managing the line of credit                          NaN    NC
#
#   ZIP code Submitted via Date sent to company  \
# 0    35180         Phone           01/27/2016
# 1    278XX         Phone           08/29/2014
# 2    37205      Referral           08/23/2012
# 3    43081           Web           05/08/2013
# 4    27216         Phone           09/08/2016
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0          Closed with explanation              Yes                 No
# 1  Closed with non-monetary relief              Yes                 No
# 2  Closed with non-monetary relief              Yes                 No
# 3          Closed with explanation              Yes                Yes
# 4  Closed with non-monetary relief              Yes                 No
#
#    Complaint ID
# 0       1760486
# 1       1001740
# 2        140039
# 3        401541
# 4       1970341

# %%
complaints_data.shape
# Out:
# (1824, 13)

# %%
complaints_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1824 entries, 0 to 1823
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       1824 non-null   object
#  1   Date received                 1824 non-null   object
#  2   Product                       1824 non-null   object
#  3   Issue                         1824 non-null   object
#  4   Consumer complaint narrative  44 non-null     object
#  5   State                         1801 non-null   object
#  6   ZIP code                      1789 non-null   object
#  7   Submitted via                 1824 non-null   object
#  8   Date sent to company          1824 non-null   object
#  9   Company response to consumer  1824 non-null   object
#  10  Timely response?              1824 non-null   object
#  11  Consumer disputed?            1824 non-null   object
#  12  Complaint ID                  1824 non-null   int64
# dtypes: int64(1), object(12)
# memory usage: 185.4+ KB
